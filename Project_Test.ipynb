# %% [markdown]
# **Kütüphanelerin Eklenmesi**

# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Raporun Dataframe Olarak Okunması**

# %%
df = pd.read_excel("/content/drive/My Drive/project1/rapor105.xls",sheet_name="Rapor")
df = pd.DataFrame(data=df.values,columns=["Dosya Dizini","Class","R1","G1","B1","R2","G2","B2","C1","M1","Y1","K1","C2","M2","Y2","K2","PERCENT1","PERCENT2","Renk Sayisi"])

# %%
df
# Out:
#                                          Dosya Dizini  ... Renk Sayisi
# 0   /content/drive/My Drive/rtestsaves_/rtest3save...  ...           2
# 1   /content/drive/My Drive/rtestsaves_/rtest3save...  ...           2
# 2   /content/drive/My Drive/rtestsaves_/rtest3save...  ...           2
# 3   /content/drive/My Drive/rtestsaves_/rtest3save...  ...           2
# 4   /content/drive/My Drive/rtestsaves_/rtest3save...  ...           2
# 5   /content/drive/My Drive/rtestsaves_/rtest3save...  ...           2
# 6   /content/drive/My Drive/rtestsaves_/rtest3save...  ...           2
# 7   /content/drive/My Drive/rtestsaves_/rtest3save...  ...           2
# 8   /content/drive/My Drive/rtestsaves_/rtest3save...  ...           2
# 9   /content/drive/My Drive/rtestsaves_/rtest3save...  ...           2
# 10  /content/drive/My Drive/rtestsaves_/rtest3save...  ...           2
# 11  /content/drive/My Drive/rtestsaves_/rtest3save...  ...           2
# 12  /content/drive/My Drive/rtestsaves_/rtest3save...  ...           2
# 13  /content/drive/My Drive/rtestsaves_/rtest3save...  ...           2
# 14  /content/drive/My Drive/rtestsaves_/rtest3save...  ...           2
# 15  /content/drive/My Drive/rtestsaves_/rtest3save...  ...           2
# 16  /content/drive/My Drive/rtestsaves_/rtest3save...  ...           2
# 17  /content/drive/My Drive/rtestsaves_/rtest3save...  ...           2
# 18  /content/drive/My Drive/rtestsaves_/rtest3save...  ...           2
# 19  /content/drive/My Drive/rtestsaves_/rtest3save...  ...           2
#
# [20 rows x 19 columns]

# %% [markdown]
# **Sonuçların Görselleştirilmesi**

# %%
n,m = df.shape
for i in range(0,n,1):
  array1 = df.iloc[i,:].values
  address = array1[0]
  image = cv2.imread(address)
  image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
  renk_sayisi = array1[m-1]
  if (renk_sayisi==1):
    colors = np.array([float(array1[2]),float(array1[3]),float(array1[4])])/255
    colors = colors.reshape((1,3))
    hist = np.array([1.0],dtype=np.float32)
  else:
    colors = np.array([[float(array1[2]),float(array1[3]),float(array1[4])],[float(array1[5]),float(array1[6]),float(array1[7])]])/255
    colors = colors.reshape((2,3))
    hist = np.array([float(array1[m-3]),float(array1[m-2])])

  plt.subplot(1,2,1)
  plt.imshow(image)
  plt.subplot(1,2,2)
  plt.pie(x = hist,colors=colors)
  plt.show()
